# %%
# also from linux shell
# $ pip list

# Python Tutorial: virtualenv and why you should use virtual environments
# https://www.youtube.com/watch?v=N5vscPTWKOk

# 
# https://github.com/bhrutledge/jupyter-venv

#
# https://github.com/microsoft/vscode-jupyter/wiki/Installing-Python-packages-in-Jupyter-Notebooks

# %%
# https://medium.com/@kishanck/virtual-environments-for-jupyter-notebooks-847b7a3b4da0
# !python -m ipykernel install --user --name=artvenv
# Out:
# Installed kernelspec artvenv in /home/codespace/.local/share/jupyter/kernels/artvenv

# %%
# !python -m pip list
# Out:
# Package                   Version
# ------------------------- ------------
# anyio                     4.1.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.13.1
# beautifulsoup4            4.12.2
# bleach                    6.1.0
# certifi                   2023.11.17
# cffi                      1.16.0
# charset-normalizer        3.3.2
# colorama                  0.4.6
# comm                      0.2.0
# contourpy                 1.2.0
# cycler                    0.12.1
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# exceptiongroup            1.2.0
# executing                 2.0.1
# fastjsonschema            2.19.0
# filelock                  3.13.1
# fonttools                 4.46.0
# fqdn                      1.5.1
# ...
